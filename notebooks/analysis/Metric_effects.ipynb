# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
pd.options.display.max_rows = 100

# %%
# !pwd
# Out:
# /Users/malte.luecken/helmholtz_munich/benchmarking_data_integration/scib-reproducibility/notebooks/analysis

# %%
files = !ls ../../../Paper/202109_kBET_fix/Supplementary\ Files/Results/*.csv

# %%
data = {file:pd.read_csv(file) for file in files}

# %%
data[files[0]]
# Out:
#     Unnamed: 0          Method Output Features   Scaling  Overall Score  \
# 0          319          scGen*   gene      HVG  unscaled       0.667406
# 1           43       Scanorama  embed      HVG    scaled       0.641593
# 2          235            scVI  embed      HVG  unscaled       0.636712
# 3          247         scANVI*  embed      HVG  unscaled       0.627515
# 4          320          scGen*   gene     FULL  unscaled       0.625399
# 5            7             MNN   gene      HVG  unscaled       0.620253
# 6          236            scVI  embed     FULL  unscaled       0.609465
# 7           44       Scanorama  embed     FULL    scaled       0.606155
# 8          343         fastMNN  embed      HVG  unscaled       0.604928
# 9          104  Seurat v3 RPCA   gene     FULL  unscaled       0.600383
# 10          31       Scanorama  embed      HVG  unscaled       0.595748
# 11         211           BBKNN  graph      HVG  unscaled       0.589690
# 12         248         scANVI*  embed     FULL  unscaled       0.581283
# 13         284          ComBat   gene     FULL  unscaled       0.580056
# 14         367         fastMNN   gene      HVG  unscaled       0.575728
# 15          32       Scanorama  embed     FULL  unscaled       0.570373
# 16          20             MNN   gene     FULL    scaled       0.568904
# 17         344         fastMNN  embed     FULL  unscaled       0.560481
# 18         116  Seurat v3 RPCA   gene     FULL    scaled       0.559685
# 19          55       Scanorama   gene      HVG  unscaled       0.556351
# 20         295          ComBat   gene      HVG    scaled       0.555297
# 21          56       Scanorama   gene     FULL  unscaled       0.547235
# 22           8             MNN   gene     FULL  unscaled       0.539853
# 23         103  Seurat v3 RPCA   gene      HVG  unscaled       0.538852
# 24         187         Harmony  embed      HVG  unscaled       0.538062
# 25         283          ComBat   gene      HVG  unscaled       0.534380
# 26          19             MNN   gene      HVG    scaled       0.530367
# 27         296          ComBat   gene     FULL    scaled       0.528216
# 28          68       Scanorama   gene     FULL    scaled       0.523369
# 29         115  Seurat v3 RPCA   gene      HVG    scaled       0.522445
# 30         355         fastMNN  embed      HVG    scaled       0.521865
# 31         368         fastMNN   gene     FULL  unscaled       0.515255
# 32          67       Scanorama   gene      HVG    scaled       0.513327
# 33         379         fastMNN   gene      HVG    scaled       0.510022
# 34         212           BBKNN  graph     FULL  unscaled       0.502312
# 35         331          scGen*   gene      HVG    scaled       0.495025
# 36         356         fastMNN  embed     FULL    scaled       0.493197
# 37         412    Unintegrated   gene     FULL  unscaled       0.492005
# 38         199         Harmony  embed      HVG    scaled       0.491846
# 39         307           LIGER  embed      HVG  unscaled       0.490261
# 40         200         Harmony  embed     FULL    scaled       0.484272
# 41         380         fastMNN   gene     FULL    scaled       0.471753
# 42         259           Conos  graph      HVG  unscaled       0.456317
# 43         308           LIGER  embed     FULL  unscaled       0.454391
# 44         224           BBKNN  graph     FULL    scaled       0.443721
# 45         223           BBKNN  graph      HVG    scaled       0.439807
# 46         392            DESC  embed     FULL  unscaled       0.435178
# 47         404            DESC  embed     FULL    scaled       0.433994
# 48         188         Harmony  embed     FULL  unscaled       0.425179
# 49         271           Conos  graph      HVG    scaled       0.421343
# 50         403            DESC  embed      HVG    scaled       0.419729
# 51         272           Conos  graph     FULL    scaled       0.413913
# 52         260           Conos  graph     FULL  unscaled       0.404813
# 53         391            DESC  embed      HVG  unscaled       0.392727
# 54         164          SAUCIE  embed     FULL    scaled       0.312948
# 55         163          SAUCIE  embed      HVG    scaled       0.300328
# 56         139          SAUCIE   gene      HVG    scaled       0.298846
# 57         140          SAUCIE   gene     FULL    scaled       0.297221
# 58         127          SAUCIE   gene      HVG  unscaled       0.281768
# 59         151          SAUCIE  embed      HVG  unscaled       0.281019
# 60         152          SAUCIE  embed     FULL  unscaled       0.262529
# 61         128          SAUCIE   gene     FULL  unscaled       0.261990
# 62          79   Seurat v3 CCA   gene      HVG  unscaled            NaN
# 63          80   Seurat v3 CCA   gene     FULL  unscaled            NaN
# 64          91   Seurat v3 CCA   gene      HVG    scaled            NaN
# 65          92   Seurat v3 CCA   gene     FULL    scaled            NaN
# 66         175           trVAE  embed      HVG  unscaled            NaN
# 67         176           trVAE  embed     FULL  unscaled            NaN
# 68         332          scGen*   gene     FULL    scaled            NaN
#
#     Batch Correction  PCR batch  Batch ASW  graph iLISI  ...  \
# 0           0.619712   0.593345   0.841671     0.106118  ...
# 1           0.677942   0.901327   0.955880     0.107809  ...
# 2           0.620568   0.870668   0.917481     0.078631  ...
# 3           0.589593   0.799600   0.891219     0.068181  ...
# 4           0.605967   0.594643   0.829299     0.090718  ...
# 5           0.549339   0.623340   0.923168     0.053692  ...
# 6           0.579523   0.795729   0.896165     0.062366  ...
# 7           0.629816   0.904613   0.940262     0.074805  ...
# 8           0.558267   0.589596   0.910170     0.065643  ...
# 9           0.626742   0.931048   0.873890     0.117627  ...
# 10          0.443384   0.280859   0.935620     0.055571  ...
# 11          0.764847        NaN        NaN     0.347902  ...
# 12          0.561881   0.741452   0.888894     0.059333  ...
# 13          0.604008   0.999986   0.913132     0.046378  ...
# 14          0.555838   0.589596   0.910170     0.066121  ...
# 15          0.400244   0.195645   0.896157     0.048573  ...
# 16          0.606653   0.920877   0.909883     0.058751  ...
# 17          0.497220   0.451361   0.890330     0.058164  ...
# 18          0.619137   0.909038   0.875311     0.091112  ...
# 19          0.400978   0.279265   0.883793     0.062687  ...
# 20          0.623186   1.000000   0.923382     0.065576  ...
# 21          0.361804   0.203349   0.852493     0.050829  ...
# 22          0.468445   0.472658   0.893050     0.027936  ...
# 23          0.649137   0.924265   0.871259     0.146790  ...
# 24          0.582346   0.826209   0.892598     0.083355  ...
# 25          0.629181   0.999993   0.932872     0.067213  ...
# 26          0.630499   0.949018   0.932803     0.077323  ...
# 27          0.595338   1.000000   0.903349     0.045642  ...
# 28          0.479392   0.622343   0.874749     0.077637  ...
# 29          0.640662   0.880876   0.854202     0.117770  ...
# 30          0.705306   0.993342   0.934819     0.159391  ...
# 31          0.494730   0.451359   0.890328     0.057917  ...
# 32          0.433528   0.393375   0.873554     0.086853  ...
# 33          0.707816   0.993342   0.934819     0.163189  ...
# 34          0.575088        NaN        NaN     0.150115  ...
# 35          0.758375   0.981403   0.836751     0.153595  ...
# 36          0.655994   0.991686   0.906266     0.125262  ...
# 37          0.268841   0.000000   0.809350     0.016755  ...
# 38          0.732261   0.980883   0.939792     0.161387  ...
# 39          0.725068   0.962128   0.874465     0.195393  ...
# 40          0.703090   0.985723   0.917402     0.150959  ...
# 41          0.655471   0.991688   0.906264     0.124719  ...
# 42          0.356604        NaN        NaN     0.000000  ...
# 43          0.668379   0.928993   0.849163     0.173073  ...
# 44          0.662854        NaN        NaN     0.207965  ...
# 45          0.674761        NaN        NaN     0.204484  ...
# 46          0.353743   0.758460   0.613825     0.078757  ...
# 47          0.304447   0.707827   0.597983     0.075523  ...
# 48          0.431241   0.455316   0.852663     0.049414  ...
# 49          0.544698        NaN        NaN     0.008558  ...
# 50          0.348529   0.809105   0.559730     0.088724  ...
# 51          0.516886        NaN        NaN     0.014224  ...
# 52          0.336944        NaN        NaN     0.000000  ...
# 53          0.344862   0.791822   0.602865     0.086298  ...
# 54          0.445399   0.869891   0.810900     0.173227  ...
# 55          0.357333   0.695873   0.790968     0.176388  ...
# 56          0.357001   0.695873   0.790771     0.176008  ...
# 57          0.444640   0.869890   0.810739     0.172900  ...
# 58          0.240992   0.184596   0.738183     0.093716  ...
# 59          0.241462   0.184594   0.738753     0.093455  ...
# 60          0.192823   0.000000   0.745292     0.087288  ...
# 61          0.191984   0.000000   0.743800     0.087054  ...
# 62               NaN        NaN        NaN          NaN  ...
# 63               NaN        NaN        NaN          NaN  ...
# 64               NaN        NaN        NaN          NaN  ...
# 65               NaN        NaN        NaN          NaN  ...
# 66               NaN        NaN        NaN          NaN  ...
# 67               NaN        NaN        NaN          NaN  ...
# 68               NaN        NaN        NaN          NaN  ...
#
#     Bio conservation  NMI cluster/label  ARI cluster/label  Cell type ASW  \
# 0           0.699201           0.904241           0.849627       0.675813
# 1           0.617360           0.637543           0.540902       0.501580
# 2           0.647474           0.687811           0.544036       0.518036
# 3           0.652797           0.746849           0.612477       0.569162
# 4           0.638353           0.900034           0.849291       0.665508
# 5           0.667529           0.673820           0.527823       0.526868
# 6           0.629426           0.663141           0.421125       0.514007
# 7           0.590382           0.652132           0.476423       0.489695
# 8           0.636036           0.666366           0.538022       0.524583
# 9           0.582810           0.554957           0.333970       0.502028
# 10          0.697323           0.653553           0.481437       0.494706
# 11          0.472918           0.570298           0.493649            NaN
# 12          0.594217           0.700462           0.455761       0.547441
# 13          0.564087           0.623021           0.387489       0.470106
# 14          0.588989           0.662638           0.513788       0.524583
# 15          0.683793           0.635198           0.389922       0.479459
# 16          0.543738           0.654793           0.436432       0.470060
# 17          0.602655           0.645700           0.460215       0.510679
# 18          0.520050           0.565379           0.298926       0.479852
# 19          0.659933           0.657001           0.484309       0.493986
# 20          0.510038           0.614892           0.403773       0.470194
# 21          0.670856           0.623603           0.352234       0.480950
# 22          0.587459           0.630026           0.348784       0.512683
# 23          0.465329           0.548961           0.314138       0.478525
# 24          0.508539           0.579497           0.317616       0.439061
# 25          0.471179           0.616374           0.418517       0.488563
# 26          0.463613           0.640037           0.393536       0.496891
# 27          0.483468           0.619253           0.408835       0.454931
# 28          0.552686           0.627865           0.445939       0.488812
# 29          0.443633           0.595596           0.341584       0.490267
# 30          0.399572           0.458549           0.268701       0.482855
# 31          0.528937           0.647133           0.448223       0.510679
# 32          0.566527           0.629597           0.408774       0.475864
# 33          0.378159           0.447341           0.258708       0.482855
# 34          0.453794           0.551370           0.367828            NaN
# 35          0.319459           0.467941           0.317211       0.462195
# 36          0.384665           0.460686           0.292265       0.459313
# 37          0.640782           0.596245           0.264216       0.394360
# 38          0.331569           0.449714           0.252548       0.466077
# 39          0.333723           0.348005           0.183351       0.455978
# 40          0.338394           0.368952           0.163226       0.454058
# 41          0.349275           0.459571           0.287634       0.459313
# 42          0.522793           0.639623           0.492953            NaN
# 43          0.311732           0.411048           0.236349       0.436246
# 44          0.297633           0.374987           0.224138            NaN
# 45          0.283172           0.394261           0.245453            NaN
# 46          0.489468           0.561887           0.375130       0.519279
# 47          0.520358           0.560506           0.361273       0.500745
# 48          0.421137           0.592017           0.349267       0.342646
# 49          0.339106           0.226277           0.144317            NaN
# 50          0.467196           0.576991           0.380339       0.532752
# 51          0.345263           0.330777           0.221759            NaN
# 52          0.450059           0.595184           0.328359            NaN
# 53          0.424636           0.575068           0.356454       0.521680
# 54          0.224647           0.306935           0.146541       0.400818
# 55          0.262325           0.322686           0.159966       0.416683
# 56          0.260076           0.324750           0.167790       0.416679
# 57          0.198942           0.307404           0.138864       0.400789
# 58          0.308951           0.429721           0.206417       0.365831
# 59          0.307390           0.429738           0.199788       0.365944
# 60          0.308999           0.426448           0.230592       0.318429
# 61          0.308660           0.421475           0.229384       0.317727
# 62               NaN                NaN                NaN            NaN
# 63               NaN                NaN                NaN            NaN
# 64               NaN                NaN                NaN            NaN
# 65               NaN                NaN                NaN            NaN
# 66               NaN                NaN                NaN            NaN
# 67               NaN                NaN                NaN            NaN
# 68               NaN                NaN                NaN            NaN
#
#     isolated label F1  isolated label silhouette  graph cLISI  \
# 0            0.155460                   0.391633     1.000000
# 1            0.159606                   0.438662     0.967787
# 2            0.183759                   0.457020     0.988365
# 3            0.076483                   0.441384     0.996387
# 4            0.155627                   0.417719     1.000000
# 5            0.243669                   0.485912     0.992262
# 6            0.240570                   0.433753     0.992627
# 7            0.140711                   0.413106     0.987966
# 8            0.086478                   0.472398     0.989702
# 9            0.337565                   0.470623     0.980930
# 10           0.259611                   0.470063     0.992525
# 11           0.248603                        NaN     0.788703
# 12           0.075477                   0.422495     0.996660
# 13           0.211682                   0.383198     0.991764
# 14           0.072034                   0.472398     0.989338
# 15           0.257949                   0.508052     0.993991
# 16           0.221536                   0.368329     0.991415
# 17           0.109542                   0.467306     0.989830
# 18           0.255132                   0.406533     0.984035
# 19           0.269610                   0.456840     0.993039
# 20           0.127873                   0.381509     0.986915
# 21           0.316079                   0.500826     0.994417
# 22           0.171908                   0.451975     0.994860
# 23           0.054487                   0.397546     0.969914
# 24           0.161793                   0.384055     0.981414
# 25           0.160942                   0.405048     0.983539
# 26           0.147619                   0.402217     0.987601
# 27           0.199495                   0.365562     0.992674
# 28           0.225476                   0.551462     0.985942
# 29           0.074167                   0.369038     0.980939
# 30           0.029504                   0.455461     0.939301
# 31           0.051485                   0.467304     0.989796
# 32           0.255300                   0.474661     0.982240
# 33           0.022623                   0.455461     0.937817
# 34           0.144631                        NaN     0.886216
# 35           0.036569                   0.338421     0.967220
# 36           0.032952                   0.416131     0.957997
# 37           0.262727                   0.414654     0.995784
# 38           0.019806                   0.416578     0.948231
# 39           0.031336                   0.434664     0.934130
# 40           0.018806                   0.410907     0.951328
# 41           0.030525                   0.416130     0.957983
# 42           0.056802                        NaN     0.986355
# 43           0.045149                   0.378129     0.948897
# 44           0.018556                        NaN     0.846831
# 45           0.016156                        NaN     0.839505
# 46           0.062482                   0.464009     0.974921
# 47           0.110443                   0.470568     0.971980
# 48           0.054998                   0.344077     0.990586
# 49           0.020979                        NaN     0.964369
# 50           0.082192                   0.460575     0.971664
# 51           0.050909                        NaN     0.959628
# 52           0.086166                        NaN     0.988364
# 53           0.100154                   0.457748     0.973444
# 54           0.061244                   0.373209     0.908803
# 55           0.053019                   0.437142     0.911020
# 56           0.053846                   0.437151     0.911132
# 57           0.054602                   0.373194     0.908081
# 58           0.185093                   0.341658     0.947924
# 59           0.162602                   0.341652     0.948136
# 60           0.223301                   0.329110     0.944487
# 61           0.258636                   0.329133     0.944815
# 62                NaN                        NaN          NaN
# 63                NaN                        NaN          NaN
# 64                NaN                        NaN          NaN
# 65                NaN                        NaN          NaN
# 66                NaN                        NaN          NaN
# 67                NaN                        NaN          NaN
# 68                NaN                        NaN          NaN
#
#     CC conservation  HVG conservation  trajectory conservation
# 0          0.491212          0.416649                 0.925860
# 1          0.706393               NaN                 0.888212
# 2          0.569934               NaN                 0.934886
# 3          0.652344               NaN                 0.905722
# 4          0.413542          0.237884                 0.661730
# 5          0.782074          0.342327                 0.863365
# 6          0.555435               NaN                 0.938736
# 7          0.659911               NaN                 0.913838
# 8          0.704683               NaN                 0.905399
# 9          0.679879          0.255777                 0.721897
# 10         0.737492               NaN                 0.972919
# 11              NaN               NaN                 0.682456
# 12         0.606892               NaN                 0.932522
# 13         0.861972          0.241858                 0.908986
# 14         0.704682          0.326219                 0.922428
# 15         0.676743               NaN                 0.976953
# 16         0.782170          0.088224                 0.924070
# 17         0.603320               NaN                 0.911996
# 18         0.757497          0.126783                 0.792726
# 19         0.741353          0.411009                 0.977264
# 20         0.697006          0.255500                 0.922334
# 21         0.844842          0.290891                 0.977800
# 22         0.933565          0.196986                 0.812266
# 23         0.602126          0.413116                 0.923949
# 24         0.663183               NaN                 0.839913
# 25         0.705442          0.375990                 0.309337
# 26         0.770876          0.290557                 0.261818
# 27         0.772256          0.067029                 0.683992
# 28         0.672584          0.121942                 0.411472
# 29         0.493036          0.291162                 0.897326
# 30         0.612017               NaN                 0.529849
# 31         0.603314          0.193209                 0.911611
# 32         0.718378          0.272496                 0.616316
# 33         0.612019          0.277025                 0.562843
# 34              NaN               NaN                 0.659257
# 35         0.305223          0.332867                 0.677872
# 36         0.679489               NaN                 0.441497
# 37         1.000000          1.000000                 0.734417
# 38         0.562850               NaN                 0.345588
# 39         0.469010               NaN                 0.650779
# 40         0.632139               NaN                 0.545480
# 41         0.679494          0.118290                 0.463317
# 42              NaN               NaN                 0.528339
# 43         0.447976               NaN                 0.556405
# 44              NaN               NaN                 0.869659
# 45              NaN               NaN                 0.798022
# 46         0.620658               NaN                 0.524376
# 47         0.679590               NaN                 0.581621
# 48         0.580990               NaN                 0.915930
# 49              NaN               NaN                 0.849611
# 50         0.540951               NaN                 0.394056
# 51              NaN               NaN                 0.604587
# 52              NaN               NaN                 0.392952
# 53         0.508604               NaN                 0.169114
# 54         0.413086               NaN                 0.470841
# 55         0.443937               NaN                 0.388484
# 56         0.443937          0.275222                 0.389901
# 57         0.413086          0.093281                 0.470440
# 58         0.488851          0.368282                 0.434621
# 59         0.488850               NaN                 0.498868
# 60         0.469210               NaN                 0.515172
# 61         0.469210          0.226006                 0.543440
# 62              NaN               NaN                      NaN
# 63              NaN               NaN                      NaN
# 64              NaN               NaN                      NaN
# 65              NaN               NaN                      NaN
# 66              NaN               NaN                      NaN
# 67              NaN               NaN                      NaN
# 68              NaN               NaN                      NaN
#
# [69 rows x 22 columns]

# %% [markdown]
# # Check min-max-scaled score contributions for each method

# %%
batch_scores = ['PCR batch', 'Batch ASW', 'graph iLISI', 'graph connectivity', 'kBET']
bio_scores = ['NMI cluster/label', 'ARI cluster/label', 'Cell type ASW', 'isolated label F1', 'isolated label silhouette', 'graph cLISI', 'CC conservation', 'HVG conservation', 'trajectory conservation']

# %%
def max_min_scale_cols(df):
    return((df - df.min())/(df.max() - df.min()))

# %%
data[files[0]].columns
# Out:
# Index(['Unnamed: 0', 'Method', 'Output', 'Features', 'Scaling',
#        'Overall Score', 'Batch Correction', 'PCR batch', 'Batch ASW',
#        'graph iLISI', 'graph connectivity', 'kBET', 'Bio conservation',
#        'NMI cluster/label', 'ARI cluster/label', 'Cell type ASW',
#        'isolated label F1', 'isolated label silhouette', 'graph cLISI',
#        'CC conservation', 'HVG conservation', 'trajectory conservation'],
#       dtype='object')

# %%
# Generate metric result ranks per method
data_mm_scaled = dict()

for file in data:
    data_mm_scaled[file] = max_min_scale_cols(data[file][[col for col in batch_scores+bio_scores if col in data[file].columns]])

    #Save  method ID output
    data_mm_scaled[file]['method_id'] = ['_'.join(data[file][['Method', 'Output', 'Features', 'Scaling']].values[i]) for i in range(data[file].shape[0])]
    data_mm_scaled[file]['Bio conservation'] = data[file]['Bio conservation']
    data_mm_scaled[file]['Batch Correction'] = data[file]['Batch Correction']
    data_mm_scaled[file]['Overall Score'] = data[file]['Overall Score']

    data_mm_scaled[file] = data_mm_scaled[file][~data_mm_scaled[file]['method_id'].isin(['Unintegrated_gene_FULL_unscaled'])]
    
    for col in batch_scores+bio_scores:
        if col not in data[file].columns:
            continue
        else:
            data_mm_scaled[file][col+'_rank'] = data_mm_scaled[file][col].rank(ascending=False)

# %%
# Average rank per method across tasks
merged = pd.concat(data_mm_scaled.values())

# %%
mean_ranks_per_method = merged.groupby(['method_id']).agg({col+'_rank':np.nanmean for col in batch_scores+bio_scores})

# %%
mean_ranks_per_method.loc[['Scanorama_embed_HVG_scaled', 'scANVI*_embed_HVG_unscaled', 'scGen*_gene_HVG_unscaled', 'fastMNN_embed_HVG_unscaled', 
                           'Harmony_embed_HVG_unscaled', 'Seurat v3 CCA_gene_HVG_unscaled', 'scVI_embed_HVG_unscaled', 'Seurat v3 RPCA_gene_HVG_scaled', 
                          'trVAE_embed_HVG_unscaled', 'BBKNN_graph_HVG_unscaled']]
# Out:
#                                  PCR batch_rank  Batch ASW_rank  \
# method_id
# Scanorama_embed_HVG_scaled            22.285714        2.571429
# scANVI*_embed_HVG_unscaled            28.000000       23.428571
# scGen*_gene_HVG_unscaled              42.166667       37.833333
# fastMNN_embed_HVG_unscaled            36.000000       16.857143
# Harmony_embed_HVG_unscaled            30.000000       20.428571
# Seurat v3 CCA_gene_HVG_unscaled       23.200000       37.400000
# scVI_embed_HVG_unscaled               19.428571       21.142857
# Seurat v3 RPCA_gene_HVG_scaled        31.400000       34.600000
# trVAE_embed_HVG_unscaled              27.800000       18.400000
# BBKNN_graph_HVG_unscaled              33.000000             NaN
#
#                                  graph iLISI_rank  graph connectivity_rank  \
# method_id
# Scanorama_embed_HVG_scaled              19.285714                22.285714
# scANVI*_embed_HVG_unscaled              34.142857                10.571429
# scGen*_gene_HVG_unscaled                28.833333                 8.833333
# fastMNN_embed_HVG_unscaled              34.428571                24.357143
# Harmony_embed_HVG_unscaled              24.285714                33.714286
# Seurat v3 CCA_gene_HVG_unscaled         18.600000                32.800000
# scVI_embed_HVG_unscaled                 30.571429                16.285714
# Seurat v3 RPCA_gene_HVG_scaled          29.800000                27.200000
# trVAE_embed_HVG_unscaled                33.600000                27.100000
# BBKNN_graph_HVG_unscaled                10.428571                11.571429
#
#                                  kBET_rank  NMI cluster/label_rank  \
# method_id
# Scanorama_embed_HVG_scaled       21.000000               14.500000
# scANVI*_embed_HVG_unscaled       32.166667                5.785714
# scGen*_gene_HVG_unscaled         15.166667                2.833333
# fastMNN_embed_HVG_unscaled       26.166667               12.928571
# Harmony_embed_HVG_unscaled       29.833333               23.714286
# Seurat v3 CCA_gene_HVG_unscaled  39.000000               29.600000
# scVI_embed_HVG_unscaled          35.500000               14.428571
# Seurat v3 RPCA_gene_HVG_scaled   23.000000               26.400000
# trVAE_embed_HVG_unscaled         26.600000               39.400000
# BBKNN_graph_HVG_unscaled         30.166667               29.285714
#
#                                  ARI cluster/label_rank  Cell type ASW_rank  \
# method_id
# Scanorama_embed_HVG_scaled                    14.071429           33.285714
# scANVI*_embed_HVG_unscaled                     6.357143           10.428571
# scGen*_gene_HVG_unscaled                       2.666667            4.500000
# fastMNN_embed_HVG_unscaled                    13.357143           14.000000
# Harmony_embed_HVG_unscaled                    21.285714           20.428571
# Seurat v3 CCA_gene_HVG_unscaled               26.600000           28.400000
# scVI_embed_HVG_unscaled                       13.142857           24.857143
# Seurat v3 RPCA_gene_HVG_scaled                28.400000           18.800000
# trVAE_embed_HVG_unscaled                      36.400000           49.400000
# BBKNN_graph_HVG_unscaled                      19.000000                 NaN
#
#                                  isolated label F1_rank  \
# method_id
# Scanorama_embed_HVG_scaled                    17.214286
# scANVI*_embed_HVG_unscaled                    21.500000
# scGen*_gene_HVG_unscaled                      13.666667
# fastMNN_embed_HVG_unscaled                    22.785714
# Harmony_embed_HVG_unscaled                    33.285714
# Seurat v3 CCA_gene_HVG_unscaled               38.800000
# scVI_embed_HVG_unscaled                       24.285714
# Seurat v3 RPCA_gene_HVG_scaled                28.200000
# trVAE_embed_HVG_unscaled                      27.400000
# BBKNN_graph_HVG_unscaled                      37.857143
#
#                                  isolated label silhouette_rank  \
# method_id
# Scanorama_embed_HVG_scaled                            35.571429
# scANVI*_embed_HVG_unscaled                            15.857143
# scGen*_gene_HVG_unscaled                              33.500000
# fastMNN_embed_HVG_unscaled                            28.857143
# Harmony_embed_HVG_unscaled                            27.285714
# Seurat v3 CCA_gene_HVG_unscaled                       25.600000
# scVI_embed_HVG_unscaled                               18.571429
# Seurat v3 RPCA_gene_HVG_scaled                        27.600000
# trVAE_embed_HVG_unscaled                              24.400000
# BBKNN_graph_HVG_unscaled                                    NaN
#
#                                  graph cLISI_rank  CC conservation_rank  \
# method_id
# Scanorama_embed_HVG_scaled              35.428571             21.800000
# scANVI*_embed_HVG_unscaled              11.928571             30.600000
# scGen*_gene_HVG_unscaled                 9.166667             33.500000
# fastMNN_embed_HVG_unscaled              18.000000             22.800000
# Harmony_embed_HVG_unscaled              22.928571             18.400000
# Seurat v3 CCA_gene_HVG_unscaled         29.500000             39.666667
# scVI_embed_HVG_unscaled                 26.857143             36.600000
# Seurat v3 RPCA_gene_HVG_scaled          25.700000             29.250000
# trVAE_embed_HVG_unscaled                48.200000             47.333333
# BBKNN_graph_HVG_unscaled                57.285714             16.000000
#
#                                  HVG conservation_rank  \
# method_id
# Scanorama_embed_HVG_scaled                         NaN
# scANVI*_embed_HVG_unscaled                         NaN
# scGen*_gene_HVG_unscaled                           5.0
# fastMNN_embed_HVG_unscaled                         NaN
# Harmony_embed_HVG_unscaled                         NaN
# Seurat v3 CCA_gene_HVG_unscaled                    3.0
# scVI_embed_HVG_unscaled                            NaN
# Seurat v3 RPCA_gene_HVG_scaled                    11.8
# trVAE_embed_HVG_unscaled                           NaN
# BBKNN_graph_HVG_unscaled                           NaN
#
#                                  trajectory conservation_rank
# method_id
# Scanorama_embed_HVG_scaled                               18.0
# scANVI*_embed_HVG_unscaled                               22.0
# scGen*_gene_HVG_unscaled                                  4.5
# fastMNN_embed_HVG_unscaled                               23.0
# Harmony_embed_HVG_unscaled                               17.5
# Seurat v3 CCA_gene_HVG_unscaled                          56.0
# scVI_embed_HVG_unscaled                                  22.5
# Seurat v3 RPCA_gene_HVG_scaled                           37.5
# trVAE_embed_HVG_unscaled                                 42.0
# BBKNN_graph_HVG_unscaled                                 30.0

# %%
mean_ranks_per_method.loc[[idx for idx in mean_ranks_per_method.index if idx.startswith('Scanorama')]]
# Out:
#                                PCR batch_rank  Batch ASW_rank  \
# method_id
# Scanorama_embed_FULL_scaled         26.500000        2.500000
# Scanorama_embed_FULL_unscaled       47.428571       20.428571
# Scanorama_embed_HVG_scaled          22.285714        2.571429
# Scanorama_embed_HVG_unscaled        43.428571       13.000000
# Scanorama_gene_FULL_scaled          41.166667       39.500000
# Scanorama_gene_FULL_unscaled        51.000000       32.000000
# Scanorama_gene_HVG_scaled           30.142857       36.714286
# Scanorama_gene_HVG_unscaled         45.000000       33.285714
#
#                                graph iLISI_rank  graph connectivity_rank  \
# method_id
# Scanorama_embed_FULL_scaled           33.666667                25.000000
# Scanorama_embed_FULL_unscaled         53.714286                39.142857
# Scanorama_embed_HVG_scaled            19.285714                22.285714
# Scanorama_embed_HVG_unscaled          48.571429                39.714286
# Scanorama_gene_FULL_scaled            38.333333                43.666667
# Scanorama_gene_FULL_unscaled          52.785714                42.142857
# Scanorama_gene_HVG_scaled             25.285714                40.857143
# Scanorama_gene_HVG_unscaled           44.714286                42.071429
#
#                                kBET_rank  NMI cluster/label_rank  \
# method_id
# Scanorama_embed_FULL_scaled    35.000000               17.583333
# Scanorama_embed_FULL_unscaled  53.083333               23.714286
# Scanorama_embed_HVG_scaled     21.000000               14.500000
# Scanorama_embed_HVG_unscaled   48.750000               13.500000
# Scanorama_gene_FULL_scaled     50.333333               29.083333
# Scanorama_gene_FULL_unscaled   52.250000               26.428571
# Scanorama_gene_HVG_scaled      47.666667               19.714286
# Scanorama_gene_HVG_unscaled    54.250000               20.000000
#
#                                ARI cluster/label_rank  Cell type ASW_rank  \
# method_id
# Scanorama_embed_FULL_scaled                 22.083333           36.666667
# Scanorama_embed_FULL_unscaled               30.285714           36.000000
# Scanorama_embed_HVG_scaled                  14.071429           33.285714
# Scanorama_embed_HVG_unscaled                18.642857           25.714286
# Scanorama_gene_FULL_scaled                  28.750000           27.166667
# Scanorama_gene_FULL_unscaled                34.285714           30.714286
# Scanorama_gene_HVG_scaled                   17.857143           20.142857
# Scanorama_gene_HVG_unscaled                 25.428571           17.142857
#
#                                isolated label F1_rank  \
# method_id
# Scanorama_embed_FULL_scaled                 18.750000
# Scanorama_embed_FULL_unscaled               22.214286
# Scanorama_embed_HVG_scaled                  17.214286
# Scanorama_embed_HVG_unscaled                24.285714
# Scanorama_gene_FULL_scaled                  19.166667
# Scanorama_gene_FULL_unscaled                19.142857
# Scanorama_gene_HVG_scaled                   19.714286
# Scanorama_gene_HVG_unscaled                 18.071429
#
#                                isolated label silhouette_rank  \
# method_id
# Scanorama_embed_FULL_scaled                         28.666667
# Scanorama_embed_FULL_unscaled                       18.142857
# Scanorama_embed_HVG_scaled                          35.571429
# Scanorama_embed_HVG_unscaled                        30.857143
# Scanorama_gene_FULL_scaled                          18.000000
# Scanorama_gene_FULL_unscaled                        17.142857
# Scanorama_gene_HVG_scaled                           18.571429
# Scanorama_gene_HVG_unscaled                         29.142857
#
#                                graph cLISI_rank  CC conservation_rank  \
# method_id
# Scanorama_embed_FULL_scaled           33.916667                  31.0
# Scanorama_embed_FULL_unscaled         16.785714                  17.6
# Scanorama_embed_HVG_scaled            35.428571                  21.8
# Scanorama_embed_HVG_unscaled          14.000000                  23.8
# Scanorama_gene_FULL_scaled            27.666667                  21.0
# Scanorama_gene_FULL_unscaled          14.214286                  11.2
# Scanorama_gene_HVG_scaled             28.428571                  23.2
# Scanorama_gene_HVG_unscaled           12.428571                  21.0
#
#                                HVG conservation_rank  \
# method_id
# Scanorama_embed_FULL_scaled                      NaN
# Scanorama_embed_FULL_unscaled                    NaN
# Scanorama_embed_HVG_scaled                       NaN
# Scanorama_embed_HVG_unscaled                     NaN
# Scanorama_gene_FULL_scaled                 25.333333
# Scanorama_gene_FULL_unscaled               15.500000
# Scanorama_gene_HVG_scaled                  11.857143
# Scanorama_gene_HVG_unscaled                 4.857143
#
#                                trajectory conservation_rank
# method_id
# Scanorama_embed_FULL_scaled                            22.0
# Scanorama_embed_FULL_unscaled                           3.0
# Scanorama_embed_HVG_scaled                             18.0
# Scanorama_embed_HVG_unscaled                           12.0
# Scanorama_gene_FULL_scaled                             56.0
# Scanorama_gene_FULL_unscaled                           11.5
# Scanorama_gene_HVG_scaled                              24.0
# Scanorama_gene_HVG_unscaled                            12.5

# %%
metric_scaling_effects = pd.DataFrame(index=mean_ranks_per_method.columns, columns=['UH_unscaled_prop', 'UH_unscaled_num', 'Total_UH_vals', 'UH_metric_effect', 'UQ_unscaled_prop', 'UQ_unscaled_num', 'Total_UQ_vals', 'UQ_metric_effect'])
# Note: UH = upper half; UQ = upper quarter

for col in mean_ranks_per_method:
    sorted_vals = mean_ranks_per_method[col].sort_values()
    sorted_vals = sorted_vals[~np.isnan(sorted_vals)]
    sorted_idx = sorted_vals.index
    
    upper_half = round(len(sorted_idx)/2)
    upper_quarter = round(len(sorted_idx)/4)
    
    res = [True if idx.endswith('unscaled') else False for idx in sorted_idx[:upper_half]]
    metric_scaling_effects['UH_unscaled_prop'][col] = np.mean(res)
    metric_scaling_effects['UH_unscaled_num'][col] = np.sum(res)
    metric_scaling_effects['Total_UH_vals'][col] = len(res)
    metric_scaling_effects['UH_metric_effect'][col] = np.abs(np.mean(res) - 0.5)

    res = [True if idx.endswith('unscaled') else False for idx in sorted_idx[:upper_quarter]]
    metric_scaling_effects['UQ_unscaled_prop'][col] = np.mean(res)
    metric_scaling_effects['UQ_unscaled_num'][col] = np.sum(res)
    metric_scaling_effects['Total_UQ_vals'][col] = len(res)
    metric_scaling_effects['UQ_metric_effect'][col] = np.abs(np.mean(res) - 0.5)

# %%
metric_scaling_effects.sort_values(by='UH_metric_effect', ascending=False)
metric_scaling_effects.sort_values(by='UQ_metric_effect', ascending=False)
# Out:
#                                UH_unscaled_prop UH_unscaled_num Total_UH_vals  \
# trajectory conservation_rank           0.735294              25            34
# graph cLISI_rank                       0.705882              24            34
# isolated label silhouette_rank              0.7              21            30
# HVG conservation_rank                    0.6875              11            16
# NMI cluster/label_rank                 0.676471              23            34
# ARI cluster/label_rank                 0.676471              23            34
# PCR batch_rank                         0.333333              11            33
# isolated label F1_rank                 0.647059              22            34
# Cell type ASW_rank                     0.633333              19            30
# graph connectivity_rank                0.617647              21            34
# CC conservation_rank                   0.606061              20            33
# Batch ASW_rank                              0.6              18            30
# graph iLISI_rank                       0.411765              14            34
# kBET_rank                              0.470588              16            34
#
#                                UH_metric_effect UQ_unscaled_prop  \
# trajectory conservation_rank           0.235294         0.882353
# graph cLISI_rank                       0.205882         0.882353
# isolated label silhouette_rank              0.2         0.733333
# HVG conservation_rank                    0.1875            0.875
# NMI cluster/label_rank                 0.176471         0.764706
# ARI cluster/label_rank                 0.176471         0.823529
# PCR batch_rank                         0.166667            0.125
# isolated label F1_rank                 0.147059         0.529412
# Cell type ASW_rank                     0.133333         0.666667
# graph connectivity_rank                0.117647         0.588235
# CC conservation_rank                   0.106061           0.8125
# Batch ASW_rank                              0.1              0.4
# graph iLISI_rank                      0.0882353         0.294118
# kBET_rank                             0.0294118         0.176471
#
#                                UQ_unscaled_num Total_UQ_vals UQ_metric_effect
# trajectory conservation_rank                15            17         0.382353
# graph cLISI_rank                            15            17         0.382353
# isolated label silhouette_rank              11            15         0.233333
# HVG conservation_rank                        7             8            0.375
# NMI cluster/label_rank                      13            17         0.264706
# ARI cluster/label_rank                      14            17         0.323529
# PCR batch_rank                               2            16            0.375
# isolated label F1_rank                       9            17        0.0294118
# Cell type ASW_rank                          10            15         0.166667
# graph connectivity_rank                     10            17        0.0882353
# CC conservation_rank                        13            16           0.3125
# Batch ASW_rank                               6            15              0.1
# graph iLISI_rank                             5            17         0.205882
# kBET_rank                                    3            17         0.323529
#                                UH_unscaled_prop UH_unscaled_num Total_UH_vals  \
# graph cLISI_rank                       0.705882              24            34
# trajectory conservation_rank           0.735294              25            34
# PCR batch_rank                         0.333333              11            33
# HVG conservation_rank                    0.6875              11            16
# kBET_rank                              0.470588              16            34
# ARI cluster/label_rank                 0.676471              23            34
# CC conservation_rank                   0.606061              20            33
# NMI cluster/label_rank                 0.676471              23            34
# isolated label silhouette_rank              0.7              21            30
# graph iLISI_rank                       0.411765              14            34
# Cell type ASW_rank                     0.633333              19            30
# Batch ASW_rank                              0.6              18            30
# graph connectivity_rank                0.617647              21            34
# isolated label F1_rank                 0.647059              22            34
#
#                                UH_metric_effect UQ_unscaled_prop  \
# graph cLISI_rank                       0.205882         0.882353
# trajectory conservation_rank           0.235294         0.882353
# PCR batch_rank                         0.166667            0.125
# HVG conservation_rank                    0.1875            0.875
# kBET_rank                             0.0294118         0.176471
# ARI cluster/label_rank                 0.176471         0.823529
# CC conservation_rank                   0.106061           0.8125
# NMI cluster/label_rank                 0.176471         0.764706
# isolated label silhouette_rank              0.2         0.733333
# graph iLISI_rank                      0.0882353         0.294118
# Cell type ASW_rank                     0.133333         0.666667
# Batch ASW_rank                              0.1              0.4
# graph connectivity_rank                0.117647         0.588235
# isolated label F1_rank                 0.147059         0.529412
#
#                                UQ_unscaled_num Total_UQ_vals UQ_metric_effect
# graph cLISI_rank                            15            17         0.382353
# trajectory conservation_rank                15            17         0.382353
# PCR batch_rank                               2            16            0.375
# HVG conservation_rank                        7             8            0.375
# kBET_rank                                    3            17         0.323529
# ARI cluster/label_rank                      14            17         0.323529
# CC conservation_rank                        13            16           0.3125
# NMI cluster/label_rank                      13            17         0.264706
# isolated label silhouette_rank              11            15         0.233333
# graph iLISI_rank                             5            17         0.205882
# Cell type ASW_rank                          10            15         0.166667
# Batch ASW_rank                               6            15              0.1
# graph connectivity_rank                     10            17        0.0882353
# isolated label F1_rank                       9            17        0.0294118

# %%
mean_ranks_per_method['kBET_rank'].sort_values()
# Out:
# method_id
# scGen*_gene_HVG_scaled                5.833333
# Harmony_embed_HVG_scaled              7.500000
# fastMNN_embed_HVG_scaled             10.666667
# fastMNN_gene_HVG_scaled              11.000000
# Harmony_embed_FULL_scaled            13.333333
# DESC_embed_HVG_scaled                13.500000
# scGen*_gene_FULL_unscaled            13.666667
# DESC_embed_HVG_unscaled              14.333333
# scGen*_gene_HVG_unscaled             15.166667
# Conos_graph_HVG_scaled               15.833333
# fastMNN_embed_FULL_scaled            16.166667
# scGen*_gene_FULL_scaled              16.200000
# fastMNN_gene_FULL_scaled             16.666667
# BBKNN_graph_FULL_scaled              18.833333
# Conos_graph_FULL_scaled              19.166667
# BBKNN_graph_HVG_scaled               19.666667
# Scanorama_embed_HVG_scaled           21.000000
# Seurat v3 RPCA_gene_HVG_scaled       23.000000
# LIGER_embed_HVG_unscaled             23.500000
# DESC_embed_FULL_unscaled             24.916667
# fastMNN_gene_HVG_unscaled            25.333333
# fastMNN_embed_HVG_unscaled           26.166667
# trVAE_embed_HVG_unscaled             26.600000
# LIGER_embed_FULL_unscaled            27.666667
# DESC_embed_FULL_scaled               29.083333
# Harmony_embed_HVG_unscaled           29.833333
# BBKNN_graph_HVG_unscaled             30.166667
# Seurat v3 CCA_gene_HVG_scaled        30.600000
# BBKNN_graph_FULL_unscaled            31.666667
# scANVI*_embed_HVG_unscaled           32.166667
# Seurat v3 RPCA_gene_FULL_scaled      32.200000
# fastMNN_embed_FULL_unscaled          32.333333
# fastMNN_gene_FULL_unscaled           33.166667
# Seurat v3 RPCA_gene_HVG_unscaled     33.800000
# SAUCIE_embed_HVG_unscaled            34.583333
# Seurat v3 RPCA_gene_FULL_unscaled    34.600000
# SAUCIE_gene_FULL_scaled              34.666667
# Scanorama_embed_FULL_scaled          35.000000
# SAUCIE_gene_HVG_unscaled             35.083333
# SAUCIE_embed_FULL_scaled             35.166667
# scVI_embed_HVG_unscaled              35.500000
# Seurat v3 CCA_gene_FULL_scaled       37.500000
# Seurat v3 CCA_gene_FULL_unscaled     38.000000
# SAUCIE_embed_HVG_scaled              38.916667
# Seurat v3 CCA_gene_HVG_unscaled      39.000000
# SAUCIE_gene_HVG_scaled               39.083333
# MNN_gene_HVG_scaled                  40.500000
# MNN_gene_FULL_scaled                 45.666667
# SAUCIE_embed_FULL_unscaled           46.500000
# scANVI*_embed_FULL_unscaled          47.000000
# Scanorama_gene_HVG_scaled            47.666667
# scVI_embed_FULL_unscaled             47.666667
# ComBat_gene_HVG_unscaled             48.166667
# Conos_graph_FULL_unscaled            48.333333
# Conos_graph_HVG_unscaled             48.666667
# Scanorama_embed_HVG_unscaled         48.750000
# SAUCIE_gene_FULL_unscaled            49.000000
# Harmony_embed_FULL_unscaled          49.666667
# Scanorama_gene_FULL_scaled           50.333333
# MNN_gene_HVG_unscaled                50.500000
# trVAE_embed_FULL_unscaled            50.700000
# ComBat_gene_HVG_scaled               51.166667
# Scanorama_gene_FULL_unscaled         52.250000
# Scanorama_embed_FULL_unscaled        53.083333
# Scanorama_gene_HVG_unscaled          54.250000
# ComBat_gene_FULL_unscaled            56.166667
# ComBat_gene_FULL_scaled              57.416667
# MNN_gene_FULL_unscaled               59.833333
# Name: kBET_rank, dtype: float64

# %% [markdown]
# # Check Batch vs bio correction score balance per method

# %%
top_methods = ['scANVI*_embed_HVG_unscaled', 'Scanorama_embed_HVG_scaled', 'scVI_embed_HVG_unscaled', 'fastMNN_embed_HVG_unscaled', 'scGen*_gene_HVG_unscaled',  'Harmony_embed_HVG_unscaled', 
               'fastMNN_gene_HVG_unscaled', 'Seurat v3 RPCA_gene_HVG_scaled', 'BBKNN_graph_HVG_unscaled', 'Scanorama_gene_HVG_scaled', 'ComBat_gene_HVG_unscaled', 'MNN_gene_HVG_scaled', 
               'Seurat v3 CCA_gene_HVG_unscaled', 'trVAE_embed_HVG_unscaled', 'Conos_graph_FULL_unscaled', 'DESC_embed_FULL_scaled', 'LIGER_embed_HVG_unscaled', 'SAUCIE_embed_HVG_scaled', 'SAUCIE_gene_HVG_scaled', ]

# %%
thresh = 0.05

batch_v_bio_top_meth = pd.DataFrame(index=top_methods, columns=['batch_prio', 'balance', 'bio_prio'], data=np.zeros((len(top_methods),3)))

for file in data_mm_scaled:
    if 'simulations' in file:
        continue
    
    data_mm_scaled[file].index = data_mm_scaled[file]['method_id']

    for i in top_methods:
        if i not in data_mm_scaled[file].index:
            continue
            
        diff = data_mm_scaled[file]['Bio conservation'][i] - data_mm_scaled[file]['Batch Correction'][i]
        if diff < -thresh:
            batch_v_bio_top_meth['batch_prio'][i]+=1
        elif -thresh <= diff < thresh:
            batch_v_bio_top_meth['balance'][i]+=1
        else:
            batch_v_bio_top_meth['bio_prio'][i]+=1

# %%
batch_v_bio_top_meth.sort_values(by='batch_prio', ascending=False)
# Out:
#                                  batch_prio  balance  bio_prio
# SAUCIE_gene_HVG_scaled                  5.0      0.0       0.0
# SAUCIE_embed_HVG_scaled                 5.0      0.0       0.0
# LIGER_embed_HVG_unscaled                5.0      0.0       0.0
# BBKNN_graph_HVG_unscaled                5.0      0.0       0.0
# Harmony_embed_HVG_unscaled              3.0      0.0       2.0
# Seurat v3 RPCA_gene_HVG_scaled          3.0      1.0       0.0
# Scanorama_embed_HVG_scaled              3.0      2.0       0.0
# Seurat v3 CCA_gene_HVG_unscaled         3.0      0.0       1.0
# fastMNN_embed_HVG_unscaled              2.0      0.0       3.0
# fastMNN_gene_HVG_unscaled               2.0      3.0       0.0
# ComBat_gene_HVG_unscaled                2.0      2.0       1.0
# MNN_gene_HVG_scaled                     2.0      1.0       1.0
# trVAE_embed_HVG_unscaled                2.0      1.0       1.0
# DESC_embed_FULL_scaled                  1.0      0.0       4.0
# scANVI*_embed_HVG_unscaled              1.0      0.0       4.0
# scGen*_gene_HVG_unscaled                1.0      0.0       3.0
# scVI_embed_HVG_unscaled                 1.0      4.0       0.0
# Scanorama_gene_HVG_scaled               1.0      1.0       3.0
# Conos_graph_FULL_unscaled               0.0      1.0       4.0

# %%
batch_v_bio_top_meth.sort_values(by='batch_prio', ascending=False).to_csv('Batch_vs_bio_priority_per_RNA_task.csv')

# %% [markdown]
# Batch prio:
# - SAUCIE
# - LIGER
# - BBKNN
# - Seurat
#
# Balance:
# - scVI
# - (fastMNN gene)
# - Scanorama
#
# Bio prio:
# - scANVI
# - scGen
# - DESC
# - Conos
