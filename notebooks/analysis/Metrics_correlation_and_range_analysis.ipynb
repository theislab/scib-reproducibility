# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /Users/malte.luecken/helmholtz_munich/benchmarking_data_integration/scib-reproducibility/notebooks/analysis

# %%
files = !ls ../../../Paper/202109_kBET_fix/Supplementary\ Files/Results/*.csv

# %%
data = {file:pd.read_csv(file) for file in files}

# %%
data[files[0]]
# Out:
#     Unnamed: 0         Method Output Features   Scaling  Overall Score  \
# 0          319         scGen*   gene      HVG  unscaled       0.668017
# 1          235           scVI  embed      HVG  unscaled       0.634913
# 2           43      Scanorama  embed      HVG    scaled       0.630803
# 3          320         scGen*   gene     FULL  unscaled       0.620692
# 4          247        scANVI*  embed      HVG  unscaled       0.619449
# ..         ...            ...    ...      ...       ...            ...
# 64          91  Seurat v3 CCA   gene      HVG    scaled            NaN
# 65          92  Seurat v3 CCA   gene     FULL    scaled            NaN
# 66         175          trVAE  embed      HVG  unscaled            NaN
# 67         176          trVAE  embed     FULL  unscaled            NaN
# 68         332         scGen*   gene     FULL    scaled            NaN
#
#     Batch Correction  PCR batch  Batch ASW  graph iLISI  ...  \
# 0           0.621240   0.593345   0.841671     0.106118  ...
# 1           0.616071   0.870668   0.917481     0.078631  ...
# 2           0.650968   0.901327   0.955880     0.107809  ...
# 3           0.594200   0.594643   0.829299     0.090718  ...
# 4           0.569427   0.799600   0.891219     0.068181  ...
# ..               ...        ...        ...          ...  ...
# 64               NaN        NaN        NaN          NaN  ...
# 65               NaN        NaN        NaN          NaN  ...
# 66               NaN        NaN        NaN          NaN  ...
# 67               NaN        NaN        NaN          NaN  ...
# 68               NaN        NaN        NaN          NaN  ...
#
#     Bio conservation  NMI cluster/label  ARI cluster/label  Cell type ASW  \
# 0           0.699201           0.904241           0.849627       0.675813
# 1           0.647474           0.687811           0.544036       0.518036
# 2           0.617360           0.637543           0.540902       0.501580
# 3           0.638353           0.900034           0.849291       0.665508
# 4           0.652797           0.746849           0.612477       0.569162
# ..               ...                ...                ...            ...
# 64               NaN                NaN                NaN            NaN
# 65               NaN                NaN                NaN            NaN
# 66               NaN                NaN                NaN            NaN
# 67               NaN                NaN                NaN            NaN
# 68               NaN                NaN                NaN            NaN
#
#     isolated label F1  isolated label silhouette  graph cLISI  \
# 0            0.155460                   0.391633     1.000000
# 1            0.183759                   0.457020     0.988365
# 2            0.159606                   0.438662     0.967787
# 3            0.155627                   0.417719     1.000000
# 4            0.076483                   0.441384     0.996387
# ..                ...                        ...          ...
# 64                NaN                        NaN          NaN
# 65                NaN                        NaN          NaN
# 66                NaN                        NaN          NaN
# 67                NaN                        NaN          NaN
# 68                NaN                        NaN          NaN
#
#     CC conservation  HVG conservation  trajectory conservation
# 0          0.491212          0.416649                 0.925860
# 1          0.569934               NaN                 0.934886
# 2          0.706393               NaN                 0.888212
# 3          0.413542          0.237884                 0.661730
# 4          0.652344               NaN                 0.905722
# ..              ...               ...                      ...
# 64              NaN               NaN                      NaN
# 65              NaN               NaN                      NaN
# 66              NaN               NaN                      NaN
# 67              NaN               NaN                      NaN
# 68              NaN               NaN                      NaN
#
# [69 rows x 22 columns]

# %% [markdown]
# # Concatenate all metrics tasks

# %%
merged = pd.concat(data.values())

# %%
merged.columns
# Out:
# Index(['Unnamed: 0', 'Method', 'Output', 'Features', 'Scaling',
#        'Overall Score', 'Batch Correction', 'PCR batch', 'Batch ASW',
#        'graph iLISI', 'graph connectivity', 'kBET', 'Bio conservation',
#        'NMI cluster/label', 'ARI cluster/label', 'Cell type ASW',
#        'isolated label F1', 'isolated label silhouette', 'graph cLISI',
#        'CC conservation', 'HVG conservation', 'trajectory conservation'],
#       dtype='object')

# %%
#Drop NA results
merged = merged.loc[~np.isnan(merged['Overall Score']),:]

# %%
#Drop non-metrics columns
merged = merged.drop(columns=['Unnamed: 0', 'Method', 'Output', 'Features', 'Scaling',
       'Overall Score', 'Batch Correction', 'Bio conservation'])

# %%
merged
# Out:
#     PCR batch  Batch ASW  graph iLISI  graph connectivity      kBET  \
# 0    0.593345   0.841671     0.106118            0.973165  0.215315
# 1    0.870668   0.917481     0.078631            0.921558  0.065287
# 2    0.901327   0.955880     0.107809            0.771782  0.137193
# 3    0.594643   0.829299     0.090718            0.929681  0.214376
# 4    0.799600   0.891219     0.068181            0.880477  0.060845
# ..        ...        ...          ...                 ...       ...
# 60        NaN        NaN     0.278785            1.000000  0.048844
# 61   0.000000   0.699457     0.159569            0.557284  0.001258
# 62   0.000000   0.699453     0.159467            0.557284  0.001289
# 63   0.000000   0.652234     0.159430            0.397708  0.000000
# 64   0.000000   0.652243     0.158493            0.397723  0.000000
#
#     NMI cluster/label  ARI cluster/label  Cell type ASW  isolated label F1  \
# 0            0.904241           0.849627       0.675813           0.155460
# 1            0.687811           0.544036       0.518036           0.183759
# 2            0.637543           0.540902       0.501580           0.159606
# 3            0.900034           0.849291       0.665508           0.155627
# 4            0.746849           0.612477       0.569162           0.076483
# ..                ...                ...            ...                ...
# 60           0.165141           0.088985            NaN           0.398508
# 61           0.136133           0.077083       0.393583           0.358264
# 62           0.137155           0.068634       0.393583           0.318718
# 63           0.133741           0.028885       0.384295           0.297224
# 64           0.134606           0.034079       0.384295           0.340185
#
#     isolated label silhouette  graph cLISI  CC conservation  HVG conservation  \
# 0                    0.391633     1.000000         0.491212          0.416649
# 1                    0.457020     0.988365         0.569934               NaN
# 2                    0.438662     0.967787         0.706393               NaN
# 3                    0.417719     1.000000         0.413542          0.237884
# 4                    0.441384     0.996387         0.652344               NaN
# ..                        ...          ...              ...               ...
# 60                        NaN     0.889310              NaN               NaN
# 61                   0.399749     0.897569              NaN               NaN
# 62                   0.399749     0.898244              NaN          0.084446
# 63                   0.389249     0.919573              NaN          0.266496
# 64                   0.389249     0.919848              NaN               NaN
#
#     trajectory conservation
# 0                  0.925860
# 1                  0.934886
# 2                  0.888212
# 3                  0.661730
# 4                  0.905722
# ..                      ...
# 60                      NaN
# 61                      NaN
# 62                      NaN
# 63                      NaN
# 64                      NaN
#
# [441 rows x 14 columns]

# %% [markdown]
# # Create correlation plot

# %%
metrics_corr = merged.corr()

# %%
metrics_corr
# Out:
#                            PCR batch  Batch ASW  graph iLISI  \
# PCR batch                   1.000000   0.331122     0.406834
# Batch ASW                   0.331122   1.000000     0.272741
# graph iLISI                 0.406834   0.272741     1.000000
# graph connectivity          0.458716   0.448233     0.212335
# kBET                        0.372828   0.100500     0.557387
# NMI cluster/label           0.160400   0.299812     0.248565
# ARI cluster/label           0.238390   0.411750     0.413852
# Cell type ASW               0.231394  -0.039637     0.242245
# isolated label F1           0.075092   0.116796     0.009832
# isolated label silhouette   0.189542   0.071489     0.094040
# graph cLISI                -0.070974  -0.043810    -0.356293
# CC conservation            -0.119309   0.252487    -0.078332
# HVG conservation           -0.390054  -0.306226    -0.120983
# trajectory conservation     0.015774   0.507494    -0.097422
#
#                            graph connectivity      kBET  NMI cluster/label  \
# PCR batch                            0.458716  0.372828           0.160400
# Batch ASW                            0.448233  0.100500           0.299812
# graph iLISI                          0.212335  0.557387           0.248565
# graph connectivity                   1.000000  0.087172           0.507117
# kBET                                 0.087172  1.000000           0.196616
# NMI cluster/label                    0.507117  0.196616           1.000000
# ARI cluster/label                    0.548494  0.288628           0.934524
# Cell type ASW                        0.519917  0.216060           0.662472
# isolated label F1                    0.306273 -0.012458           0.321535
# isolated label silhouette            0.317974  0.146992           0.297020
# graph cLISI                          0.110591 -0.108883           0.365586
# CC conservation                      0.009500 -0.260801           0.292469
# HVG conservation                    -0.107066 -0.153734           0.138845
# trajectory conservation              0.514673 -0.090170           0.474055
#
#                            ARI cluster/label  Cell type ASW  \
# PCR batch                           0.238390       0.231394
# Batch ASW                           0.411750      -0.039637
# graph iLISI                         0.413852       0.242245
# graph connectivity                  0.548494       0.519917
# kBET                                0.288628       0.216060
# NMI cluster/label                   0.934524       0.662472
# ARI cluster/label                   1.000000       0.594561
# Cell type ASW                       0.594561       1.000000
# isolated label F1                   0.236879       0.413699
# isolated label silhouette           0.318365       0.412222
# graph cLISI                         0.225693       0.527967
# CC conservation                     0.211427      -0.053541
# HVG conservation                    0.034850       0.099033
# trajectory conservation             0.427448       0.336569
#
#                            isolated label F1  isolated label silhouette  \
# PCR batch                           0.075092                   0.189542
# Batch ASW                           0.116796                   0.071489
# graph iLISI                         0.009832                   0.094040
# graph connectivity                  0.306273                   0.317974
# kBET                               -0.012458                   0.146992
# NMI cluster/label                   0.321535                   0.297020
# ARI cluster/label                   0.236879                   0.318365
# Cell type ASW                       0.413699                   0.412222
# isolated label F1                   1.000000                   0.263311
# isolated label silhouette           0.263311                   1.000000
# graph cLISI                         0.226035                   0.175761
# CC conservation                    -0.028445                   0.063280
# HVG conservation                    0.039893                  -0.059251
# trajectory conservation             0.294267                   0.374652
#
#                            graph cLISI  CC conservation  HVG conservation  \
# PCR batch                    -0.070974        -0.119309         -0.390054
# Batch ASW                    -0.043810         0.252487         -0.306226
# graph iLISI                  -0.356293        -0.078332         -0.120983
# graph connectivity            0.110591         0.009500         -0.107066
# kBET                         -0.108883        -0.260801         -0.153734
# NMI cluster/label             0.365586         0.292469          0.138845
# ARI cluster/label             0.225693         0.211427          0.034850
# Cell type ASW                 0.527967        -0.053541          0.099033
# isolated label F1             0.226035        -0.028445          0.039893
# isolated label silhouette     0.175761         0.063280         -0.059251
# graph cLISI                   1.000000         0.259517          0.192515
# CC conservation               0.259517         1.000000          0.155308
# HVG conservation              0.192515         0.155308          1.000000
# trajectory conservation       0.122757         0.335684          0.112153
#
#                            trajectory conservation
# PCR batch                                 0.015774
# Batch ASW                                 0.507494
# graph iLISI                              -0.097422
# graph connectivity                        0.514673
# kBET                                     -0.090170
# NMI cluster/label                         0.474055
# ARI cluster/label                         0.427448
# Cell type ASW                             0.336569
# isolated label F1                         0.294267
# isolated label silhouette                 0.374652
# graph cLISI                               0.122757
# CC conservation                           0.335684
# HVG conservation                          0.112153
# trajectory conservation                   1.000000

# %%
sns.heatmap(metrics_corr)

# %%
sns.heatmap(metrics_corr > 0.7)
plt.show()

sns.heatmap(metrics_corr > 0.6)
plt.show()

sns.heatmap(metrics_corr > 0.5)
plt.show()

# %% [markdown]
# Correlation results:
# - Only NMI/ARI cluster/label are closely correlated (pearson R=0.93) in RNA and simulation tasks
#   - this is likely the most important assessment of bio conservation, thus double metric means it is up-weighted, which may be relevant
# - Cell type ASW correlated with cluster NMI score at 0.66, but this gives different info as shown in FastMNN HVG/scaled results on mouse brain

# %% [markdown]
# # Effective range of metrics

# %%
merged.describe()
# Out:
#         PCR batch   Batch ASW  graph iLISI  graph connectivity        kBET  \
# count  393.000000  387.000000   441.000000          441.000000  402.000000
# mean     0.775596    0.829402     0.206436            0.787979    0.260492
# std      0.285108    0.115297     0.161236            0.250268    0.197918
# min      0.000000    0.313182     0.000000            0.032869    0.000000
# 25%      0.695873    0.781814     0.072440            0.661741    0.079650
# 50%      0.901297    0.859637     0.168905            0.896505    0.253280
# 75%      0.962123    0.903650     0.327411            0.984181    0.387275
# max      1.000000    0.992010     0.593243            1.000000    0.962638
#
#        NMI cluster/label  ARI cluster/label  Cell type ASW  isolated label F1  \
# count         441.000000         441.000000     387.000000         441.000000
# mean            0.682717           0.556948       0.570263           0.528840
# std             0.219118           0.298838       0.093518           0.344618
# min             0.007093           0.002259       0.239947           0.013652
# 25%             0.568383           0.314839       0.515435           0.155627
# 50%             0.690388           0.511049       0.565820           0.544499
# 75%             0.861368           0.864552       0.627630           0.844135
# max             1.000000           1.000000       0.865885           1.000000
#
#        isolated label silhouette  graph cLISI  CC conservation  \
# count                 387.000000   441.000000       275.000000
# mean                    0.514701     0.969414         0.599518
# std                     0.094947     0.061170         0.180447
# min                     0.030170     0.610511         0.126080
# 25%                     0.470133     0.972888         0.485211
# 50%                     0.514672     0.994329         0.612019
# 75%                     0.562418     1.000000         0.734078
# max                     0.890196     1.000000         1.000000
#
#        HVG conservation  trajectory conservation
# count        196.000000               131.000000
# mean           0.299479                 0.720470
# std            0.193214                 0.211714
# min            0.029739                 0.000000
# 25%            0.160003                 0.550943
# 50%            0.276955                 0.826601
# 75%            0.377617                 0.864579
# max            1.000000                 0.977800

# %% [markdown]
# Smallest range is cLISI from 0.61-1.0, with smallest effective range of 0.03 in 25% and 75% quantile, yet this metric is important to keep as BBKNN is biased in iLISI and therefore penalized in cLISI so it predominantly downweights BBKNN results to keep comparison fair.

# %% [markdown]
# # ATAC data

# %%
atac1 = pd.read_csv('../../../Paper/202109_kBET_fix/Supplementary Files/Results/ATAC/mouse_brain_atac_large_summary_scores.csv')
atac2 = pd.read_csv('../../../Paper/202109_kBET_fix/Supplementary Files/Results/ATAC/mouse_brain_atac_small_summary_scores.csv')
atac = pd.concat([atac1,atac2])

# %%
#Drop NA results
atac = atac.loc[~np.isnan(atac['Overall Score']),:]

#Drop non-metrics columns
atac = atac.drop(columns=['Unnamed: 0', 'Method', 'Output', 'Feature Space',
       'Overall Score', 'Batch Correction', 'Bio conservation'])

# %%
atac1.columns
atac2.columns
# Out:
# Index(['Unnamed: 0', 'Method', 'Output', 'Feature Space', 'Overall Score',
#        'Batch Correction', 'PCR batch', 'Batch ASW', 'iLISI',
#        'graph connectivity', 'kBET', 'Bio conservation', 'NMI cluster/label',
#        'ARI cluster/label', 'Cell type ASW', 'isolated label F1',
#        'isolated label silhouette', 'cLISI'],
#       dtype='object')
# Index(['Unnamed: 0', 'Method', 'Output', 'Feature Space', 'Overall Score',
#        'Batch Correction', 'PCR batch', 'Batch ASW', 'iLISI',
#        'graph connectivity', 'kBET', 'Bio conservation', 'NMI cluster/label',
#        'ARI cluster/label', 'Cell type ASW', 'isolated label F1',
#        'isolated label silhouette', 'cLISI'],
#       dtype='object')

# %%
atac
# Out:
#     PCR batch  Batch ASW     iLISI  graph connectivity      kBET  \
# 0    0.832315   0.932749  0.412561            0.978348  0.509328
# 1    0.996638   0.935324  0.325948            0.992911  0.297497
# 2    0.637313   0.898966  0.392901            0.859229  0.420510
# 3    0.992910   0.942639  0.269098            0.998634  0.121344
# 4    0.463422   0.969956  0.396970            0.987579  0.566593
# ..        ...        ...       ...                 ...       ...
# 55   0.739526   0.811123  0.577905            0.713325  0.243281
# 56   0.000000   0.513662  0.080565            0.471945  0.054764
# 57   0.000000   0.463333  0.025514            0.195351  0.002886
# 58        NaN        NaN  0.000000            0.596218  0.000389
# 59        NaN        NaN  0.000000            0.536314  0.000992
#
#     NMI cluster/label  ARI cluster/label  Cell type ASW  isolated label F1  \
# 0            0.750537           0.719046       0.585103           0.724123
# 1            0.704479           0.616729       0.594801           0.886003
# 2            0.668963           0.509371       0.650241           0.893904
# 3            0.697919           0.583343       0.615208           0.941176
# 4            0.652050           0.450867       0.538148           0.921678
# ..                ...                ...            ...                ...
# 55           0.391198           0.215952       0.502840           0.293932
# 56           0.504633           0.191902       0.595636           0.625613
# 57           0.538904           0.217068       0.613970           0.745046
# 58           0.419309           0.303863            NaN           0.833609
# 59           0.374532           0.308401            NaN           0.695840
#
#     isolated label silhouette     cLISI
# 0                    0.441312  0.998807
# 1                    0.506610  0.999054
# 2                    0.572404  0.999343
# 3                    0.520949  1.000000
# 4                    0.516579  0.990864
# ..                        ...       ...
# 55                   0.448820  0.708019
# 56                   0.529892  0.968892
# 57                   0.541819  0.981961
# 58                        NaN  0.535917
# 59                        NaN  0.389638
#
# [96 rows x 11 columns]

# %% [markdown]
# # ATAC analysis

# %%
atac_corr = atac.corr()
atac_corr
# Out:
#                            PCR batch  Batch ASW     iLISI  graph connectivity  \
# PCR batch                   1.000000   0.433045  0.520341            0.172368
# Batch ASW                   0.433045   1.000000  0.339150            0.583857
# iLISI                       0.520341   0.339150  1.000000            0.122832
# graph connectivity          0.172368   0.583857  0.122832            1.000000
# kBET                        0.328520   0.556186  0.657598            0.135350
# NMI cluster/label          -0.078818   0.056826 -0.184739            0.516804
# ARI cluster/label           0.039308   0.293632 -0.007647            0.627868
# Cell type ASW               0.196768   0.307622 -0.265447            0.386776
# isolated label F1          -0.247849   0.138430 -0.479091            0.408117
# isolated label silhouette   0.130548   0.425718 -0.280354            0.444996
# cLISI                      -0.302440  -0.194249 -0.204997            0.231636
#
#                                kBET  NMI cluster/label  ARI cluster/label  \
# PCR batch                  0.328520          -0.078818           0.039308
# Batch ASW                  0.556186           0.056826           0.293632
# iLISI                      0.657598          -0.184739          -0.007647
# graph connectivity         0.135350           0.516804           0.627868
# kBET                       1.000000          -0.281094          -0.076494
# NMI cluster/label         -0.281094           1.000000           0.885476
# ARI cluster/label         -0.076494           0.885476           1.000000
# Cell type ASW             -0.156349           0.642903           0.500919
# isolated label F1         -0.326365           0.763689           0.626117
# isolated label silhouette -0.086311           0.468309           0.406943
# cLISI                      0.043723           0.451169           0.353064
#
#                            Cell type ASW  isolated label F1  \
# PCR batch                       0.196768          -0.247849
# Batch ASW                       0.307622           0.138430
# iLISI                          -0.265447          -0.479091
# graph connectivity              0.386776           0.408117
# kBET                           -0.156349          -0.326365
# NMI cluster/label               0.642903           0.763689
# ARI cluster/label               0.500919           0.626117
# Cell type ASW                   1.000000           0.599710
# isolated label F1               0.599710           1.000000
# isolated label silhouette       0.850892           0.599442
# cLISI                           0.271308           0.374767
#
#                            isolated label silhouette     cLISI
# PCR batch                                   0.130548 -0.302440
# Batch ASW                                   0.425718 -0.194249
# iLISI                                      -0.280354 -0.204997
# graph connectivity                          0.444996  0.231636
# kBET                                       -0.086311  0.043723
# NMI cluster/label                           0.468309  0.451169
# ARI cluster/label                           0.406943  0.353064
# Cell type ASW                               0.850892  0.271308
# isolated label F1                           0.599442  0.374767
# isolated label silhouette                   1.000000  0.098245
# cLISI                                       0.098245  1.000000

# %%
sns.heatmap(atac_corr)

# %%
sns.heatmap(atac_corr > 0.7)
plt.show()

sns.heatmap(atac_corr > 0.6)
plt.show()

sns.heatmap(atac_corr > 0.5)
plt.show()

# %%
atac.describe()
# Out:
#        PCR batch  Batch ASW      iLISI  graph connectivity       kBET  \
# count  84.000000  84.000000  96.000000           96.000000  96.000000
# mean    0.449078   0.810914   0.319319            0.889703   0.215686
# std     0.364732   0.125244   0.185977            0.174216   0.176662
# min     0.000000   0.447484   0.000000            0.195351   0.000000
# 25%     0.000000   0.745653   0.197559            0.830217   0.106777
# 50%     0.470736   0.834308   0.362627            0.980639   0.157634
# 75%     0.761289   0.914613   0.415491            0.992469   0.301909
# max     0.999766   0.971783   0.762560            0.999734   0.642817
#
#        NMI cluster/label  ARI cluster/label  Cell type ASW  isolated label F1  \
# count          96.000000          96.000000      84.000000          96.000000
# mean            0.541379           0.416449       0.550699           0.697352
# std             0.171455           0.198976       0.084317           0.247693
# min             0.162147           0.050342       0.208820           0.134503
# 25%             0.401223           0.259836       0.525107           0.503480
# 50%             0.553904           0.386583       0.549188           0.763776
# 75%             0.694497           0.576816       0.604392           0.912875
# max             0.788624           0.809482       0.706901           0.990179
#
#        isolated label silhouette      cLISI
# count                  84.000000  96.000000
# mean                    0.493078   0.919411
# std                     0.080600   0.114075
# min                     0.200401   0.389638
# 25%                     0.482685   0.872614
# 50%                     0.506917   0.966812
# 75%                     0.532767   0.994569
# max                     0.672062   1.000000

# %%
atac.describe()
# Out:
#        PCR batch  Batch ASW      iLISI  graph connectivity       kBET  \
# count  84.000000  84.000000  96.000000           96.000000  96.000000
# mean    0.449078   0.810914   0.319319            0.889703   0.215686
# std     0.364732   0.125244   0.185977            0.174216   0.176662
# min     0.000000   0.447484   0.000000            0.195351   0.000000
# 25%     0.000000   0.745653   0.197559            0.830217   0.106777
# 50%     0.470736   0.834308   0.362627            0.980639   0.157634
# 75%     0.761289   0.914613   0.415491            0.992469   0.301909
# max     0.999766   0.971783   0.762560            0.999734   0.642817
#
#        NMI cluster/label  ARI cluster/label  Cell type ASW  isolated label F1  \
# count          96.000000          96.000000      84.000000          96.000000
# mean            0.541379           0.416449       0.550699           0.697352
# std             0.171455           0.198976       0.084317           0.247693
# min             0.162147           0.050342       0.208820           0.134503
# 25%             0.401223           0.259836       0.525107           0.503480
# 50%             0.553904           0.386583       0.549188           0.763776
# 75%             0.694497           0.576816       0.604392           0.912875
# max             0.788624           0.809482       0.706901           0.990179
#
#        isolated label silhouette      cLISI
# count                  84.000000  96.000000
# mean                    0.493078   0.919411
# std                     0.080600   0.114075
# min                     0.200401   0.389638
# 25%                     0.482685   0.872614
# 50%                     0.506917   0.966812
# 75%                     0.532767   0.994569
# max                     0.672062   1.000000

# %% [markdown]
# ATAC correlations are slightly higher, and (effective) ranges are a little lower, as methods perform poorly across the tasks.
#
# However, NMI and ARI are not as highly correlated on ATAC data, as on RNA data (pearson r=0.88 instead of 0.93)
